# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import geopandas as gpd
import pandas as pd

# %%
file = "timeframes.csv"
crimes = pd.read_csv(file)
into = "Regionsinto.csv"
intodf = pd.read_csv(into)
outof = "Regionsout.csv"
outofdf = pd.read_csv(outof)
dvin = "Regionsdvinto.csv"
dvindf = pd.read_csv(dvin)
dvindf
# Out:
#                   Website Region      Period   Rate
# 0  Goldfields-Esperance District  2020-05-01   7.45
# 1        Great Southern District  2020-05-01  -4.35
# 2             Kimberley District  2020-05-01  12.45
# 3              Mandurah District  2020-05-01 -10.00
# 4            Metropolitan Region  2020-05-01 -11.35
# 5     Mid West-Gascoyne District  2020-05-01 -23.85
# 6               Pilbara District  2020-05-01   2.05
# 7            South West District  2020-05-01   2.94
# 8             Wheatbelt District  2020-05-01 -33.33

# %%
path = 'Police_Districts.shp'
districts = gpd.read_file(path)
colours = ['b','g','r','c','m','y','w','k','saddlebrown','pink','slategray','lime','orange','darkviolet','olive']
names = ['Metropolitan Region','Metropolitan Region','Metropolitan Region','Metropolitan Region','Metropolitan Region','Metropolitan Region','Metropolitan Region','Metropolitan Region','South West District','Great Southern District','Wheatbelt District','Mid West-Gascoyne District','Goldfields-Esperance District','Pilbara District','Kimberley District']
districts['colours'] = colours
#cmap = plt.get_cmap('Sequential')
districts['Website Region'] = names

# %%
districts.plot(color = districts['colours'],figsize=(12,7))
plt.show()

# %%
districts
# Out:
#                                              geometry      colours  \
# 0   POLYGON ((115.68175 -31.47691, 115.68467 -31.4...            b
# 1   MULTIPOLYGON (((115.89872 -32.18033, 115.90067...            g
# 2   POLYGON ((115.98349 -32.00971, 115.98364 -32.0...            r
# 3   MULTIPOLYGON (((115.84468 -32.00154, 115.84453...            c
# 4   POLYGON ((115.75992 -31.90809, 115.75992 -31.9...            m
# 5   POLYGON ((115.83165 -31.84572, 115.83195 -31.8...            y
# 6   POLYGON ((116.05442 -31.60022, 116.05442 -31.6...            w
# 7   POLYGON ((115.97852 -31.92114, 115.98165 -31.9...            k
# 8   POLYGON ((116.01948 -32.75648, 116.01964 -32.7...  saddlebrown
# 9   MULTIPOLYGON (((117.94801 -34.99529, 117.94797...         pink
# 10  POLYGON ((118.50798 -29.61416, 118.51261 -29.6...    slategray
# 11  MULTIPOLYGON (((113.95336 -29.04370, 113.95201...         lime
# 12  POLYGON ((130.00006 -23.19196, 130.00006 -23.1...       orange
# 13  MULTIPOLYGON (((115.53181 -21.38920, 115.53205...   darkviolet
# 14  MULTIPOLYGON (((123.70797 -16.10657, 123.70826...        olive
#
#                    Website Region
# 0             Metropolitan Region
# 1             Metropolitan Region
# 2             Metropolitan Region
# 3             Metropolitan Region
# 4             Metropolitan Region
# 5             Metropolitan Region
# 6             Metropolitan Region
# 7             Metropolitan Region
# 8             South West District
# 9         Great Southern District
# 10             Wheatbelt District
# 11     Mid West-Gascoyne District
# 12  Goldfields-Esperance District
# 13               Pilbara District
# 14             Kimberley District

# %%
merged = pd.merge(districts,intodf,on='Website Region',how='left')

# %%
merged
# Out:
#                                              geometry      colours  \
# 0   POLYGON ((115.68175 -31.47691, 115.68467 -31.4...            b
# 1   MULTIPOLYGON (((115.89872 -32.18033, 115.90067...            g
# 2   POLYGON ((115.98349 -32.00971, 115.98364 -32.0...            r
# 3   MULTIPOLYGON (((115.84468 -32.00154, 115.84453...            c
# 4   POLYGON ((115.75992 -31.90809, 115.75992 -31.9...            m
# 5   POLYGON ((115.83165 -31.84572, 115.83195 -31.8...            y
# 6   POLYGON ((116.05442 -31.60022, 116.05442 -31.6...            w
# 7   POLYGON ((115.97852 -31.92114, 115.98165 -31.9...            k
# 8   POLYGON ((116.01948 -32.75648, 116.01964 -32.7...  saddlebrown
# 9   MULTIPOLYGON (((117.94801 -34.99529, 117.94797...         pink
# 10  POLYGON ((118.50798 -29.61416, 118.51261 -29.6...    slategray
# 11  MULTIPOLYGON (((113.95336 -29.04370, 113.95201...         lime
# 12  POLYGON ((130.00006 -23.19196, 130.00006 -23.1...       orange
# 13  MULTIPOLYGON (((115.53181 -21.38920, 115.53205...   darkviolet
# 14  MULTIPOLYGON (((123.70797 -16.10657, 123.70826...        olive
#
#                    Website Region      Period   Rate
# 0             Metropolitan Region         NaN    NaN
# 1             Metropolitan Region         NaN    NaN
# 2             Metropolitan Region         NaN    NaN
# 3             Metropolitan Region         NaN    NaN
# 4             Metropolitan Region         NaN    NaN
# 5             Metropolitan Region         NaN    NaN
# 6             Metropolitan Region         NaN    NaN
# 7             Metropolitan Region         NaN    NaN
# 8             South West District  2020-04-01 -12.14
# 9         Great Southern District  2020-04-01 -25.54
# 10             Wheatbelt District  2020-04-01 -21.34
# 11     Mid West-Gascoyne District  2020-04-01 -17.24
# 12  Goldfields-Esperance District  2020-04-01 -22.59
# 13               Pilbara District  2020-04-01 -11.41
# 14             Kimberley District  2020-04-01 -34.28

# %%
merged.plot(column = merged['Rate'],figsize=(12,7),legend=True)
plt.title("Percent Change in Crime Rate per Region", pad=15)
plt.savefig("crimemap.png",bbox_inches='tight')
plt.show()

# %%
mergeddv = pd.merge(districts,dvindf,on='Website Region',how='left')

mergeddv
# Out:
#                                              geometry      colours  \
# 0   POLYGON ((115.68175 -31.47691, 115.68467 -31.4...            b
# 1   MULTIPOLYGON (((115.89872 -32.18033, 115.90067...            g
# 2   POLYGON ((115.98349 -32.00971, 115.98364 -32.0...            r
# 3   MULTIPOLYGON (((115.84468 -32.00154, 115.84453...            c
# 4   POLYGON ((115.75992 -31.90809, 115.75992 -31.9...            m
# 5   POLYGON ((115.83165 -31.84572, 115.83195 -31.8...            y
# 6   POLYGON ((116.05442 -31.60022, 116.05442 -31.6...            w
# 7   POLYGON ((115.97852 -31.92114, 115.98165 -31.9...            k
# 8   POLYGON ((116.01948 -32.75648, 116.01964 -32.7...  saddlebrown
# 9   MULTIPOLYGON (((117.94801 -34.99529, 117.94797...         pink
# 10  POLYGON ((118.50798 -29.61416, 118.51261 -29.6...    slategray
# 11  MULTIPOLYGON (((113.95336 -29.04370, 113.95201...         lime
# 12  POLYGON ((130.00006 -23.19196, 130.00006 -23.1...       orange
# 13  MULTIPOLYGON (((115.53181 -21.38920, 115.53205...   darkviolet
# 14  MULTIPOLYGON (((123.70797 -16.10657, 123.70826...        olive
#
#                    Website Region      Period   Rate
# 0             Metropolitan Region  2020-05-01 -11.35
# 1             Metropolitan Region  2020-05-01 -11.35
# 2             Metropolitan Region  2020-05-01 -11.35
# 3             Metropolitan Region  2020-05-01 -11.35
# 4             Metropolitan Region  2020-05-01 -11.35
# 5             Metropolitan Region  2020-05-01 -11.35
# 6             Metropolitan Region  2020-05-01 -11.35
# 7             Metropolitan Region  2020-05-01 -11.35
# 8             South West District  2020-05-01   2.94
# 9         Great Southern District  2020-05-01  -4.35
# 10             Wheatbelt District  2020-05-01 -33.33
# 11     Mid West-Gascoyne District  2020-05-01 -23.85
# 12  Goldfields-Esperance District  2020-05-01   7.45
# 13               Pilbara District  2020-05-01   2.05
# 14             Kimberley District  2020-05-01  12.45

# %%
mergeddv.plot(column = mergeddv['Rate'],figsize=(12,7),legend=True)
plt.title("Percent Change in Reported Domestic Violence Rate per Region", pad=15)
plt.axis('off')
plt.savefig("dvmap.png",bbox_inches='tight')
plt.show()
